# %%
import os
os.chdir("../..")
os.getcwd()
# Out:
# '/Users/toukouken/Documents/Hori/M1/mfp_prediction_api'

# %%
from logic.img_logic.generate_img import ImgGenerator
from logic.graph_logic.draw_3d_object import GraphCreator
import numpy as np

# %%
im_creator = ImgGenerator(
    Lu=150,
    Lx=450,
    Ly=450,
    pixel=2400,
    shape="triangle",
    porosity=0.3,
    misalignment=0.5,
    angle=0
)

# %%
processed_object = im_creator.generate_film_with_multi_hole()

# %%
im_creator.create_film_picture(processed_object)
# Out:
# Slice plane origin: [225.0, 225.0, 25.0]
# Slice plane normal: [0, 0, 1]

# %%
# GraphCreator.draw_3d_object(processed_object=processed_object)
