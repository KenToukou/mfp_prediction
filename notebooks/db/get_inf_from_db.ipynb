# %%
import os
os.chdir("../..")
os.getcwd()
# Out:
# '/Users/toukouken/Documents/Hori/M1/mfp_prediction_api'

# %%
from service.db.db_service import DBService
from logic.db_logic.db_connect import get_db_inf_from_yaml

# %%
DB_URL = get_db_inf_from_yaml()["mfp_db"].get("db_url","")

# %%
db_api = DBService(DB_URL)

# %%
shapes = ["circle", "triangle", "square"]
porosity = 0.3
misalignment = 0.0

# %%
db_api.get_pore_position_id(
    shape=shapes[0],
    porosity=porosity,
    normalized_misalignment=misalignment
)
# Out:
# 7.0

# %%
db_api.get_all_msd_data()
# Out:
#      pore_position_id   shape  porosity  normalized_misalignment  Thickness  \
# 0                   1  circle       0.3                     0.35      10d-9
# 1                   1  circle       0.3                     0.35      20d-9
# 2                   1  circle       0.3                     0.35      50d-9
# 3                   1  circle       0.3                     0.35     100d-9
# 4                   1  circle       0.3                     0.35     200d-9
# ..                ...     ...       ...                      ...        ...
# 508                32  circle       0.3                     0.40   50000d-9
# 509                32  circle       0.3                     0.40  100000d-9
# 510                32  circle       0.3                     0.40        inf
# 511                32  circle       0.3                     0.40  200000d-9
# 512                32  circle       0.3                     0.40  500000d-9
#
# ...

# %%
# db_api.get_msd_data(
#     shape=shapes[0],
#     porosity=porosity,
#     normalized_misalignment=misalignment
# )
# Out:
#     pore_position_id   shape  porosity  normalized_misalignment   Thickness  \
# 0                  7  circle       0.3                      0.0        1d-9
# 1                  7  circle       0.3                      0.0        2d-9
# 2                  7  circle       0.3                      0.0        5d-9
# 3                  7  circle       0.3                      0.0       10d-9
# 4                  7  circle       0.3                      0.0       20d-9
# 5                  7  circle       0.3                      0.0       50d-9
# 6                  7  circle       0.3                      0.0      100d-9
# 7                  7  circle       0.3                      0.0      200d-9
# 8                  7  circle       0.3                      0.0      500d-9
# 9                  7  circle       0.3                      0.0     1000d-9
# 10                 7  circle       0.3                      0.0     2000d-9
# ...

# %%
# db_api.delete_mfp_by_id(pore_info_id=1)
